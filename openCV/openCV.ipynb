# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Photo-2.jpeg")
plt.imshow(img) # by default it reads image as BGR

# %%
# newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2HLS_FULL)
plt.imshow(newImg)

# %%
print(img)
# Out:
# [[[145 153 213]
#   [151 156 217]
#   [150 155 216]
#   ...
#   [102 116 145]
#   [103 117 146]
#   [106 119 151]]
#
#  [[149 154 215]
#   [150 158 218]
#   [150 158 218]
#   ...
#   [107 121 150]
#   [102 116 145]
#   [101 114 146]]
#
#  [[150 155 216]
#   [152 157 218]
#   [151 156 217]
#   ...
#   [108 124 153]
#   [105 120 152]
#   [ 97 112 144]]
#
#  ...
#
#  [[152 177 211]
#   [149 174 208]
#   [150 172 207]
#   ...
#   [ 68 112 165]
#   [ 74 118 171]
#   [ 85 130 181]]
#
#  [[147 171 207]
#   [142 165 203]
#   [141 165 201]
#   ...
#   [ 36  65 116]
#   [ 39  67 121]
#   [ 66  97 148]]
#
#  [[139 163 199]
#   [135 159 195]
#   [133 157 193]
#   ...
#   [ 26  47  98]
#   [ 33  54 105]
#   [ 49  74 124]]]

# %%
cv2.imshow('Kushi',img)
cv2.waitKey(250)
cv2.destroyAllWindows()
